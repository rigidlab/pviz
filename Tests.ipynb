# %%
from pviz import space
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f2c93b94-f474-4ed8-8eda-e165a2b03785">Loading BokehJS ...</span>
#     </div>

# %%
p = space(500,500,x_range=(-5,5),y_range=(-5,5))
p.add_circle(1,2,radius=0.1)
p.add_rectangle(1,1)
p.plot()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6e08d0fa-f456-4806-a99a-600a05559a5b"></div>
# </div>
