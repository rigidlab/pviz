# %%
from pviz import space
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f41ea65b-fcda-4514-9b75-277764a80798">Loading BokehJS ...</span>
#     </div>

# %%
p = space(500,500)
p.add_circle(1,2,radius=0.1)
p.add_rectangle(1,1)
p.plot()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bbe87bf8-2edc-48d6-8228-e7f94264d48e"></div>
# </div>
